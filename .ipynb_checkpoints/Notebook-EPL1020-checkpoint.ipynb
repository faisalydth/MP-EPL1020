# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# Import all packages need.

# %%
import requests as rq
import json
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# ## COLLECT & DISCOVER DATA

# %% [markdown]
# Get and collect EPL matches season 2010/11 to 2020/21 data in JSON format. Click [here](https://github.com/openfootball/football.json) for the data source.
#
# Complete URL ex: `https://raw.githubusercontent.com/openfootball/football.json/master/2010-11//en.1.json`

# %%
urlLeft = 'https://raw.githubusercontent.com/openfootball/football.json/master/'
urlRight = '/en.1.json'

seasonIntl = list(range(2010, 2021)) # season start
seasonInt2 = list(range(11, 22)) # season end

seasonStr1 = []
seasonStr2 = []
for s1, s2 in zip(seasonIntl, seasonInt2):
    seasonStr1.append(str(s1))
    seasonStr2.append(str(s2))

seasonMerge = []
for s1, s2 in zip(seasonStr1, seasonStr2):
    seasonMerge.append(urlLeft + s1 + '-' +s2 + urlRight)

# convert data to python
pythonData = []
for x in seasonMerge:
    convert = json.loads(rq.get(x).content) # get JSON content
    pythonData.append(convert)

# %%
pythonData[0] # season 2010/11
# Out:
# {'name': 'Premier League 2010/11',
#  'rounds': [{'name': 'Matchday 1',
#    'matches': [{'date': '2010-08-14',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-08-14',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [0, 4]}},
#     {'date': '2010-08-14',
#      'team1': 'Aston Villa FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2010-08-14',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-08-14',
#      'team1': 'Sunderland AFC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-08-14',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-08-14',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-08-14',
#      'team1': 'Chelsea FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [6, 0]}},
#     {'date': '2010-08-15',
#      'team1': 'Liverpool FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-08-16',
#      'team1': 'Manchester United FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [3, 0]}}]},
#   {'name': 'Matchday 2',
#    'matches': [{'date': '2010-08-21',
#      'team1': 'West Ham United FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2010-08-21',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-08-21',
#      'team1': 'Stoke City FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-08-21',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [0, 6]}},
#     {'date': '2010-08-21',
#      'team1': 'Everton FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-08-21',
#      'team1': 'Birmingham City FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-08-21',
#      'team1': 'Arsenal FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [6, 0]}},
#     {'date': '2010-08-22',
#      'team1': 'Newcastle United FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [6, 0]}},
#     {'date': '2010-08-22',
#      'team1': 'Fulham FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-08-23',
#      'team1': 'Manchester City FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [3, 0]}}]},
#   {'name': 'Matchday 3',
#    'matches': [{'date': '2010-08-28',
#      'team1': 'Blackpool FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-08-28',
#      'team1': 'Manchester United FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2010-08-28',
#      'team1': 'Chelsea FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-08-28',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-08-28',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2010-08-28',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-08-29',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-08-29',
#      'team1': 'Liverpool FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-08-29',
#      'team1': 'Sunderland AFC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-08-29',
#      'team1': 'Aston Villa FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 0]}}]},
#   {'name': 'Matchday 4',
#    'matches': [{'date': '2010-09-11',
#      'team1': 'Newcastle United FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-09-11',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-09-11',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-09-11',
#      'team1': 'Manchester City FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-09-11',
#      'team1': 'Arsenal FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [4, 1]}},
#     {'date': '2010-09-11',
#      'team1': 'West Ham United FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2010-09-11',
#      'team1': 'Fulham FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-09-11',
#      'team1': 'Everton FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [3, 3]}},
#     {'date': '2010-09-12',
#      'team1': 'Birmingham City FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-09-13',
#      'team1': 'Stoke City FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [2, 1]}}]},
#   {'name': 'Matchday 5',
#    'matches': [{'date': '2010-09-18',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2010-09-18',
#      'team1': 'Sunderland AFC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-09-18',
#      'team1': 'Everton FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2010-09-18',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2010-09-18',
#      'team1': 'Stoke City FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-09-18',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-09-18',
#      'team1': 'Aston Villa FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-09-19',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-09-19',
#      'team1': 'Chelsea FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [4, 0]}},
#     {'date': '2010-09-19',
#      'team1': 'Manchester United FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [3, 2]}}]},
#   {'name': 'Matchday 6',
#    'matches': [{'date': '2010-09-25',
#      'team1': 'Blackpool FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-09-25',
#      'team1': 'Birmingham City FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-09-25',
#      'team1': 'Arsenal FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 3]}},
#     {'date': '2010-09-25',
#      'team1': 'Liverpool FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-09-25',
#      'team1': 'Fulham FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-09-25',
#      'team1': 'Manchester City FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-09-25',
#      'team1': 'West Ham United FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-09-26',
#      'team1': 'Newcastle United FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-09-26',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-09-26',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [2, 2]}}]},
#   {'name': 'Matchday 7',
#    'matches': [{'date': '2010-10-02',
#      'team1': 'Stoke City FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-10-02',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-10-02',
#      'team1': 'Birmingham City FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-10-02',
#      'team1': 'Sunderland AFC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-10-02',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-10-02',
#      'team1': 'West Ham United FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-10-02',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-10-03',
#      'team1': 'Liverpool FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-10-03',
#      'team1': 'Chelsea FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-10-03',
#      'team1': 'Manchester City FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [2, 1]}}]},
#   {'name': 'Matchday 8',
#    'matches': [{'date': '2010-10-16',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-10-16',
#      'team1': 'Arsenal FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-10-16',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-10-16',
#      'team1': 'Manchester United FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-10-16',
#      'team1': 'Fulham FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-10-16',
#      'team1': 'Aston Villa FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-10-16',
#      'team1': 'Newcastle United FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-10-17',
#      'team1': 'Everton FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-10-17',
#      'team1': 'Blackpool FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [2, 3]}},
#     {'date': '2010-10-18',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [0, 0]}}]},
#   {'name': 'Matchday 9',
#    'matches': [{'date': '2010-10-23',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-10-23',
#      'team1': 'Sunderland AFC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-10-23',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-10-23',
#      'team1': 'Birmingham City FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-10-23',
#      'team1': 'Chelsea FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-10-23',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-10-23',
#      'team1': 'West Ham United FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-10-24',
#      'team1': 'Stoke City FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-10-24',
#      'team1': 'Liverpool FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-10-24',
#      'team1': 'Manchester City FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [0, 3]}}]},
#   {'name': 'Matchday 10',
#    'matches': [{'date': '2010-10-30',
#      'team1': 'Fulham FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-10-30',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-10-30',
#      'team1': 'Manchester United FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-10-30',
#      'team1': 'Everton FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-10-30',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-10-30',
#      'team1': 'Arsenal FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-10-31',
#      'team1': 'Aston Villa FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-10-31',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2010-10-31',
#      'team1': 'Newcastle United FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [5, 1]}},
#     {'date': '2010-11-01',
#      'team1': 'Blackpool FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 1]}}]},
#   {'name': 'Matchday 11',
#    'matches': [{'date': '2010-11-06',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-11-06',
#      'team1': 'Sunderland AFC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-11-06',
#      'team1': 'Blackpool FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-11-06',
#      'team1': 'Birmingham City FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-11-06',
#      'team1': 'Fulham FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-11-06',
#      'team1': 'Manchester United FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-11-06',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [4, 2]}},
#     {'date': '2010-11-07',
#      'team1': 'Liverpool FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-11-07',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-11-07',
#      'team1': 'Arsenal FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [0, 1]}}]},
#   {'name': 'Matchday 12',
#    'matches': [{'date': '2010-11-09',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-11-09',
#      'team1': 'Stoke City FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2010-11-10',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-11-10',
#      'team1': 'Newcastle United FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-11-10',
#      'team1': 'Aston Villa FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2010-11-10',
#      'team1': 'Everton FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-11-10',
#      'team1': 'Manchester City FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-11-10',
#      'team1': 'Chelsea FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-11-10',
#      'team1': 'West Ham United FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-11-10',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [1, 1]}}]},
#   {'name': 'Matchday 13',
#    'matches': [{'date': '2010-11-13',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-11-13',
#      'team1': 'Newcastle United FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-11-13',
#      'team1': 'Manchester City FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-11-13',
#      'team1': 'Aston Villa FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-11-13',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [2, 3]}},
#     {'date': '2010-11-13',
#      'team1': 'Stoke City FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-11-13',
#      'team1': 'West Ham United FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-11-13',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [4, 2]}},
#     {'date': '2010-11-14',
#      'team1': 'Everton FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-11-14',
#      'team1': 'Chelsea FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [0, 3]}}]},
#   {'name': 'Matchday 14',
#    'matches': [{'date': '2010-11-20',
#      'team1': 'Liverpool FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2010-11-20',
#      'team1': 'Blackpool FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-11-20',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [5, 1]}},
#     {'date': '2010-11-20',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [0, 3]}},
#     {'date': '2010-11-20',
#      'team1': 'Manchester United FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-11-20',
#      'team1': 'Birmingham City FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-11-20',
#      'team1': 'Arsenal FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [2, 3]}},
#     {'date': '2010-11-21',
#      'team1': 'Fulham FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [1, 4]}},
#     {'date': '2010-11-21',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-11-22',
#      'team1': 'Sunderland AFC',
#      'team2': 'Everton FC',
#      'score': {'ft': [2, 2]}}]},
#   {'name': 'Matchday 15',
#    'matches': [{'date': '2010-11-27',
#      'team1': 'Aston Villa FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [2, 4]}},
#     {'date': '2010-11-27',
#      'team1': 'Fulham FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-11-27',
#      'team1': 'Manchester United FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [7, 1]}},
#     {'date': '2010-11-27',
#      'team1': 'West Ham United FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2010-11-27',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2010-11-27',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-11-27',
#      'team1': 'Stoke City FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-11-27',
#      'team1': 'Everton FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [1, 4]}},
#     {'date': '2010-11-28',
#      'team1': 'Newcastle United FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-11-28',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [2, 1]}}]},
#   {'name': 'Matchday 16',
#    'matches': [{'date': '2010-12-04',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2010-12-04',
#      'team1': 'Birmingham City FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-12-04',
#      'team1': 'Arsenal FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-12-04',
#      'team1': 'Manchester City FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-12-04',
#      'team1': 'Chelsea FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-12-04',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2010-12-05',
#      'team1': 'Sunderland AFC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-12-05',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2010-12-06',
#      'team1': 'Liverpool FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-01-25',
#      'team1': 'Blackpool FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [2, 3]}}]},
#   {'name': 'Matchday 17',
#    'matches': [{'date': '2010-12-11',
#      'team1': 'Stoke City FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2010-12-11',
#      'team1': 'Aston Villa FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-12-11',
#      'team1': 'West Ham United FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2010-12-11',
#      'team1': 'Fulham FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-12-11',
#      'team1': 'Newcastle United FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2010-12-11',
#      'team1': 'Everton FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2010-12-12',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-12-12',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2010-12-12',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-12-13',
#      'team1': 'Manchester United FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [1, 0]}}]},
#   {'name': 'Matchday 18',
#    'matches': [{'date': '2010-12-18',
#      'team1': 'Sunderland AFC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-12-18',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-12-20',
#      'team1': 'Manchester City FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-01-25',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-01-26',
#      'team1': 'Liverpool FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-02-15',
#      'team1': 'Birmingham City FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2011-02-20',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-02-22',
#      'team1': 'Blackpool FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-02-23',
#      'team1': 'Arsenal FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-03-01',
#      'team1': 'Chelsea FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [2, 1]}}]},
#   {'name': 'Matchday 19',
#    'matches': [{'date': '2010-12-26',
#      'team1': 'Fulham FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2010-12-26',
#      'team1': 'Newcastle United FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2010-12-26',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-12-26',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-12-26',
#      'team1': 'Manchester United FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-12-26',
#      'team1': 'Aston Villa FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2010-12-26',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-12-27',
#      'team1': 'Arsenal FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-01-12',
#      'team1': 'Blackpool FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-03-09',
#      'team1': 'Everton FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [1, 1]}}]},
#   {'name': 'Matchday 20',
#    'matches': [{'date': '2010-12-28',
#      'team1': 'West Ham United FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-12-28',
#      'team1': 'Manchester City FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [4, 0]}},
#     {'date': '2010-12-28',
#      'team1': 'Stoke City FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-12-28',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2010-12-28',
#      'team1': 'Sunderland AFC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2010-12-28',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2010-12-28',
#      'team1': 'Birmingham City FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2010-12-29',
#      'team1': 'Liverpool FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2010-12-29',
#      'team1': 'Chelsea FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2010-12-29',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [2, 2]}}]},
#   {'name': 'Matchday 21',
#    'matches': [{'date': '2011-01-01',
#      'team1': 'Stoke City FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-01-01',
#      'team1': 'Birmingham City FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [0, 3]}},
#     {'date': '2011-01-01',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-01-01',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-01-01',
#      'team1': 'Sunderland AFC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-01-01',
#      'team1': 'Liverpool FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-01-01',
#      'team1': 'West Ham United FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-01-01',
#      'team1': 'Manchester City FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-01-02',
#      'team1': 'Chelsea FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [3, 3]}},
#     {'date': '2011-01-02',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [0, 1]}}]},
#   {'name': 'Matchday 22',
#    'matches': [{'date': '2011-01-04',
#      'team1': 'Fulham FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-01-04',
#      'team1': 'Manchester United FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-01-04',
#      'team1': 'Blackpool FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-01-05',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-01-05',
#      'team1': 'Aston Villa FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2011-01-05',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-01-05',
#      'team1': 'Arsenal FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-01-05',
#      'team1': 'Newcastle United FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [5, 0]}},
#     {'date': '2011-01-05',
#      'team1': 'Everton FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-01-05',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 0]}}]},
#   {'name': 'Matchday 23',
#    'matches': [{'date': '2011-01-15',
#      'team1': 'Stoke City FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-01-15',
#      'team1': 'Manchester City FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [4, 3]}},
#     {'date': '2011-01-15',
#      'team1': 'Chelsea FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-01-15',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-01-15',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2011-01-15',
#      'team1': 'West Ham United FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [0, 3]}},
#     {'date': '2011-01-16',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-01-16',
#      'team1': 'Sunderland AFC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-01-16',
#      'team1': 'Birmingham City FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-01-16',
#      'team1': 'Liverpool FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [2, 2]}}]},
#   {'name': 'Matchday 24',
#    'matches': [{'date': '2011-01-22',
#      'team1': 'Fulham FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-01-22',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [0, 3]}},
#     {'date': '2011-01-22',
#      'team1': 'Everton FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-01-22',
#      'team1': 'Blackpool FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-01-22',
#      'team1': 'Aston Villa FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-01-22',
#      'team1': 'Manchester United FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [5, 0]}},
#     {'date': '2011-01-22',
#      'team1': 'Arsenal FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-01-22',
#      'team1': 'Newcastle United FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-01-23',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-01-24',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [0, 4]}}]},
#   {'name': 'Matchday 25',
#    'matches': [{'date': '2011-02-01',
#      'team1': 'Arsenal FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-02-01',
#      'team1': 'Sunderland AFC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [2, 4]}},
#     {'date': '2011-02-01',
#      'team1': 'Manchester United FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-02-01',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-02-02',
#      'team1': 'Blackpool FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2011-02-02',
#      'team1': 'Liverpool FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-02-02',
#      'team1': 'Birmingham City FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-02-02',
#      'team1': 'Fulham FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-02-02',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2011-02-02',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [1, 0]}}]},
#   {'name': 'Matchday 26',
#    'matches': [{'date': '2011-02-05',
#      'team1': 'Aston Villa FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-02-05',
#      'team1': 'Everton FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [5, 3]}},
#     {'date': '2011-02-05',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [4, 3]}},
#     {'date': '2011-02-05',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-02-05',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-02-05',
#      'team1': 'Stoke City FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2011-02-05',
#      'team1': 'Newcastle United FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [4, 4]}},
#     {'date': '2011-02-05',
#      'team1': 'Manchester City FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-02-06',
#      'team1': 'Chelsea FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2011-02-06',
#      'team1': 'West Ham United FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [0, 1]}}]},
#   {'name': 'Matchday 27',
#    'matches': [{'date': '2011-02-12',
#      'team1': 'Sunderland AFC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-02-12',
#      'team1': 'Manchester United FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-02-12',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [3, 3]}},
#     {'date': '2011-02-12',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-02-12',
#      'team1': 'Blackpool FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-02-12',
#      'team1': 'Liverpool FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-02-12',
#      'team1': 'Birmingham City FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-02-12',
#      'team1': 'Arsenal FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-02-13',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-02-14',
#      'team1': 'Fulham FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [0, 0]}}]},
#   {'name': 'Matchday 28',
#    'matches': [{'date': '2011-02-26',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [0, 4]}},
#     {'date': '2011-02-26',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [4, 0]}},
#     {'date': '2011-02-26',
#      'team1': 'Everton FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-02-26',
#      'team1': 'Newcastle United FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-02-26',
#      'team1': 'Aston Villa FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [4, 1]}},
#     {'date': '2011-02-27',
#      'team1': 'West Ham United FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-02-27',
#      'team1': 'Manchester City FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-02-28',
#      'team1': 'Stoke City FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-20',
#      'team1': 'Chelsea FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-04-20',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [3, 3]}}]},
#   {'name': 'Matchday 29',
#    'matches': [{'date': '2011-03-05',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2011-03-05',
#      'team1': 'Manchester City FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-03-05',
#      'team1': 'West Ham United FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-03-05',
#      'team1': 'Arsenal FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-03-05',
#      'team1': 'Birmingham City FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2011-03-05',
#      'team1': 'Fulham FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2011-03-05',
#      'team1': 'Newcastle United FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-03-06',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [3, 3]}},
#     {'date': '2011-03-06',
#      'team1': 'Liverpool FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-03-07',
#      'team1': 'Blackpool FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 3]}}]},
#   {'name': 'Matchday 30',
#    'matches': [{'date': '2011-03-19',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-03-19',
#      'team1': 'Everton FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-03-19',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-03-19',
#      'team1': 'Aston Villa FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2011-03-19',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-03-19',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-03-19',
#      'team1': 'Stoke City FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [4, 0]}},
#     {'date': '2011-03-19',
#      'team1': 'Manchester United FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-03-20',
#      'team1': 'Chelsea FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-03-20',
#      'team1': 'Sunderland AFC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [0, 2]}}]},
#   {'name': 'Matchday 31',
#    'matches': [{'date': '2011-04-02',
#      'team1': 'Stoke City FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-02',
#      'team1': 'Newcastle United FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [4, 1]}},
#     {'date': '2011-04-02',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-04-02',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-04-02',
#      'team1': 'West Ham United FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [2, 4]}},
#     {'date': '2011-04-02',
#      'team1': 'Arsenal FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-04-02',
#      'team1': 'Everton FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-04-02',
#      'team1': 'Birmingham City FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-04-03',
#      'team1': 'Manchester City FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [5, 0]}},
#     {'date': '2011-04-03',
#      'team1': 'Fulham FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [3, 0]}}]},
#   {'name': 'Matchday 32',
#    'matches': [{'date': '2011-04-09',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-04-09',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2011-04-09',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [0, 3]}},
#     {'date': '2011-04-09',
#      'team1': 'Chelsea FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-04-09',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-09',
#      'team1': 'Sunderland AFC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 3]}},
#     {'date': '2011-04-09',
#      'team1': 'Manchester United FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-04-10',
#      'team1': 'Blackpool FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2011-04-10',
#      'team1': 'Aston Villa FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-04-11',
#      'team1': 'Liverpool FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [3, 0]}}]},
#   {'name': 'Matchday 33',
#    'matches': [{'date': '2011-04-16',
#      'team1': 'West Ham United FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-04-16',
#      'team1': 'Blackpool FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2011-04-16',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2011-04-16',
#      'team1': 'Birmingham City FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-04-16',
#      'team1': 'Everton FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [2, 0]}},
#     {'date': '2011-04-17',
#      'team1': 'Arsenal FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-19',
#      'team1': 'Newcastle United FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-04-26',
#      'team1': 'Stoke City FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-04-27',
#      'team1': 'Fulham FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-05-10',
#      'team1': 'Manchester City FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [1, 0]}}]},
#   {'name': 'Matchday 34',
#    'matches': [{'date': '2011-04-23',
#      'team1': 'Aston Villa FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-23',
#      'team1': 'Liverpool FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [5, 0]}},
#     {'date': '2011-04-23',
#      'team1': 'Chelsea FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-04-23',
#      'team1': 'Manchester United FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-04-23',
#      'team1': 'Blackpool FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-23',
#      'team1': 'Sunderland AFC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [4, 2]}},
#     {'date': '2011-04-23',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-23',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-04-24',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-04-25',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [0, 1]}}]},
#   {'name': 'Matchday 35',
#    'matches': [{'date': '2011-04-30',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-04-30',
#      'team1': 'Blackpool FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [0, 0]}},
#     {'date': '2011-04-30',
#      'team1': 'Sunderland AFC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [0, 3]}},
#     {'date': '2011-04-30',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-04-30',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-04-30',
#      'team1': 'Chelsea FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-05-01',
#      'team1': 'Arsenal FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-05-01',
#      'team1': 'Birmingham City FC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-05-01',
#      'team1': 'Liverpool FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [3, 0]}},
#     {'date': '2011-05-01',
#      'team1': 'Manchester City FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [2, 1]}}]},
#   {'name': 'Matchday 36',
#    'matches': [{'date': '2011-05-07',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-05-07',
#      'team1': 'Newcastle United FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-05-07',
#      'team1': 'Everton FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-05-07',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-05-07',
#      'team1': 'West Ham United FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-05-07',
#      'team1': 'Aston Villa FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-05-08',
#      'team1': 'Manchester United FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-05-08',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-05-08',
#      'team1': 'Stoke City FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [3, 1]}},
#     {'date': '2011-05-09',
#      'team1': 'Fulham FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [2, 5]}}]},
#   {'name': 'Matchday 37',
#    'matches': [{'date': '2011-05-14',
#      'team1': 'Sunderland AFC',
#      'team2': 'Wolverhampton Wanderers FC',
#      'score': {'ft': [1, 3]}},
#     {'date': '2011-05-14',
#      'team1': 'West Bromwich Albion FC',
#      'team2': 'Everton FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-05-14',
#      'team1': 'Blackburn Rovers FC',
#      'team2': 'Manchester United FC',
#      'score': {'ft': [1, 1]}},
#     {'date': '2011-05-14',
#      'team1': 'Blackpool FC',
#      'team2': 'Bolton Wanderers FC',
#      'score': {'ft': [4, 3]}},
#     {'date': '2011-05-15',
#      'team1': 'Birmingham City FC',
#      'team2': 'Fulham FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2011-05-15',
#      'team1': 'Arsenal FC',
#      'team2': 'Aston Villa FC',
#      'score': {'ft': [1, 2]}},
#     {'date': '2011-05-15',
#      'team1': 'Chelsea FC',
#      'team2': 'Newcastle United FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-05-15',
#      'team1': 'Liverpool FC',
#      'team2': 'Tottenham Hotspur FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2011-05-15',
#      'team1': 'Wigan Athletic FC',
#      'team2': 'West Ham United FC',
#      'score': {'ft': [3, 2]}},
#     {'date': '2011-05-17',
#      'team1': 'Manchester City FC',
#      'team2': 'Stoke City FC',
#      'score': {'ft': [3, 0]}}]},
#   {'name': 'Matchday 38',
#    'matches': [{'date': '2011-05-22',
#      'team1': 'Newcastle United FC',
#      'team2': 'West Bromwich Albion FC',
#      'score': {'ft': [3, 3]}},
#     {'date': '2011-05-22',
#      'team1': 'West Ham United FC',
#      'team2': 'Sunderland AFC',
#      'score': {'ft': [0, 3]}},
#     {'date': '2011-05-22',
#      'team1': 'Wolverhampton Wanderers FC',
#      'team2': 'Blackburn Rovers FC',
#      'score': {'ft': [2, 3]}},
#     {'date': '2011-05-22',
#      'team1': 'Fulham FC',
#      'team2': 'Arsenal FC',
#      'score': {'ft': [2, 2]}},
#     {'date': '2011-05-22',
#      'team1': 'Stoke City FC',
#      'team2': 'Wigan Athletic FC',
#      'score': {'ft': [0, 1]}},
#     {'date': '2011-05-22',
#      'team1': 'Manchester United FC',
#      'team2': 'Blackpool FC',
#      'score': {'ft': [4, 2]}},
#     {'date': '2011-05-22',
#      'team1': 'Bolton Wanderers FC',
#      'team2': 'Manchester City FC',
#      'score': {'ft': [0, 2]}},
#     {'date': '2011-05-22',
#      'team1': 'Everton FC',
#      'team2': 'Chelsea FC',
#      'score': {'ft': [1, 0]}},
#     {'date': '2011-05-22',
#      'team1': 'Tottenham Hotspur FC',
#      'team2': 'Birmingham City FC',
#      'score': {'ft': [2, 1]}},
#     {'date': '2011-05-22',
#      'team1': 'Aston Villa FC',
#      'team2': 'Liverpool FC',
#      'score': {'ft': [1, 0]}}]}]}

# %%
pythonData[8] # season 2018/19
# Out:
# {'name': 'Premier League 2018/19',
#  'matches': [{'round': 'Matchday 1',
#    'date': '2018-08-10',
#    'team1': 'Manchester United FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-11',
#    'team1': 'Newcastle United FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-11',
#    'team1': 'Fulham FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-11',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-11',
#    'team1': 'Watford FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-11',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-11',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-12',
#    'team1': 'Liverpool FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [4, 0]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-12',
#    'team1': 'Southampton FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 1',
#    'date': '2018-08-12',
#    'team1': 'Arsenal FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-18',
#    'team1': 'Cardiff City FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-18',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-18',
#    'team1': 'Everton FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-18',
#    'team1': 'Leicester City FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-18',
#    'team1': 'West Ham United FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-18',
#    'team1': 'Chelsea FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-19',
#    'team1': 'Manchester City FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [6, 1]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-19',
#    'team1': 'Burnley FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-19',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 2',
#    'date': '2018-08-20',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-25',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-25',
#    'team1': 'Arsenal FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-25',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-25',
#    'team1': 'Southampton FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-25',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Everton FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-25',
#    'team1': 'Liverpool FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-26',
#    'team1': 'Watford FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-26',
#    'team1': 'Fulham FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [4, 2]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-26',
#    'team1': 'Newcastle United FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 3',
#    'date': '2018-08-27',
#    'team1': 'Manchester United FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-01',
#    'team1': 'Leicester City FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-01',
#    'team1': 'Chelsea FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-01',
#    'team1': 'Everton FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-01',
#    'team1': 'West Ham United FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-01',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-01',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-01',
#    'team1': 'Manchester City FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-02',
#    'team1': 'Cardiff City FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [2, 3]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-02',
#    'team1': 'Burnley FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 4',
#    'date': '2018-09-02',
#    'team1': 'Watford FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-15',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-15',
#    'team1': 'Manchester City FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-15',
#    'team1': 'Newcastle United FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-15',
#    'team1': 'Chelsea FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [4, 1]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-15',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-15',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [4, 2]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-15',
#    'team1': 'Watford FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-16',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-16',
#    'team1': 'Everton FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 5',
#    'date': '2018-09-17',
#    'team1': 'Southampton FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Fulham FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Liverpool FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Manchester United FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Leicester City FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Burnley FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [4, 0]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Cardiff City FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 5]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-22',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-23',
#    'team1': 'West Ham United FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 6',
#    'date': '2018-09-23',
#    'team1': 'Arsenal FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'West Ham United FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'Manchester City FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'Newcastle United FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'Arsenal FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'Everton FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-29',
#    'team1': 'Chelsea FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 7',
#    'date': '2018-09-30',
#    'team1': 'Cardiff City FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 7',
#    'date': '2018-10-01',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-05',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-06',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-06',
#    'team1': 'Leicester City FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-06',
#    'team1': 'Burnley FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-06',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-06',
#    'team1': 'Watford FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [0, 4]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-06',
#    'team1': 'Manchester United FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-07',
#    'team1': 'Fulham FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 5]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-07',
#    'team1': 'Southampton FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 8',
#    'date': '2018-10-07',
#    'team1': 'Liverpool FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'Chelsea FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'Manchester City FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [5, 0]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'Newcastle United FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'Cardiff City FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [4, 2]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'West Ham United FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Southampton FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-20',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-21',
#    'team1': 'Everton FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 9',
#    'date': '2018-10-22',
#    'team1': 'Arsenal FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-27',
#    'team1': 'Fulham FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-27',
#    'team1': 'Liverpool FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [4, 1]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-27',
#    'team1': 'Southampton FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-27',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-27',
#    'team1': 'Watford FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-27',
#    'team1': 'Leicester City FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-28',
#    'team1': 'Burnley FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [0, 4]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-28',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-28',
#    'team1': 'Manchester United FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 10',
#    'date': '2018-10-29',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-03',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-03',
#    'team1': 'Newcastle United FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-03',
#    'team1': 'Everton FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-03',
#    'team1': 'Cardiff City FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-03',
#    'team1': 'West Ham United FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [4, 2]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-03',
#    'team1': 'Arsenal FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-03',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [2, 3]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-04',
#    'team1': 'Manchester City FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [6, 1]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-04',
#    'team1': 'Chelsea FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 11',
#    'date': '2018-11-05',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-10',
#    'team1': 'Cardiff City FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-10',
#    'team1': 'Newcastle United FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-10',
#    'team1': 'Leicester City FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-10',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-10',
#    'team1': 'Southampton FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-10',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-11',
#    'team1': 'Liverpool FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-11',
#    'team1': 'Chelsea FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-11',
#    'team1': 'Manchester City FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 12',
#    'date': '2018-11-11',
#    'team1': 'Arsenal FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-24',
#    'team1': 'Fulham FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-24',
#    'team1': 'Everton FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-24',
#    'team1': 'Manchester United FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-24',
#    'team1': 'West Ham United FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 4]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-24',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-24',
#    'team1': 'Watford FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-24',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-25',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-25',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 13',
#    'date': '2018-11-26',
#    'team1': 'Burnley FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 14',
#    'date': '2018-11-30',
#    'team1': 'Cardiff City FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-01',
#    'team1': 'Manchester City FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-01',
#    'team1': 'Newcastle United FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-01',
#    'team1': 'Leicester City FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-01',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-01',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-01',
#    'team1': 'Southampton FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-02',
#    'team1': 'Chelsea FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-02',
#    'team1': 'Arsenal FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [4, 2]}},
#   {'round': 'Matchday 14',
#    'date': '2018-12-02',
#    'team1': 'Liverpool FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-04',
#    'team1': 'West Ham United FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-04',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-04',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-04',
#    'team1': 'Watford FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-05',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-05',
#    'team1': 'Fulham FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-05',
#    'team1': 'Burnley FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-05',
#    'team1': 'Everton FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-05',
#    'team1': 'Manchester United FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 15',
#    'date': '2018-12-05',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 4]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'Arsenal FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'Manchester United FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [4, 1]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'Burnley FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'Cardiff City FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'West Ham United FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'Chelsea FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-08',
#    'team1': 'Leicester City FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-09',
#    'team1': 'Newcastle United FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 16',
#    'date': '2018-12-10',
#    'team1': 'Everton FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-15',
#    'team1': 'Manchester City FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-15',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-15',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-15',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-15',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-15',
#    'team1': 'Watford FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-15',
#    'team1': 'Fulham FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-16',
#    'team1': 'Southampton FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-16',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 17',
#    'date': '2018-12-16',
#    'team1': 'Liverpool FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-21',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'Arsenal FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'Manchester City FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [2, 3]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'Newcastle United FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'Chelsea FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'West Ham United FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-22',
#    'team1': 'Cardiff City FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [1, 5]}},
#   {'round': 'Matchday 18',
#    'date': '2018-12-23',
#    'team1': 'Everton FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [2, 6]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Fulham FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Liverpool FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [4, 0]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [5, 0]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Manchester United FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Leicester City FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Burnley FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [1, 5]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-26',
#    'team1': 'Watford FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 19',
#    'date': '2018-12-27',
#    'team1': 'Southampton FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-29',
#    'team1': 'Leicester City FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-29',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-29',
#    'team1': 'Watford FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-29',
#    'team1': 'Fulham FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-29',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-29',
#    'team1': 'Liverpool FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [5, 1]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-30',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-30',
#    'team1': 'Burnley FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-30',
#    'team1': 'Southampton FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 20',
#    'date': '2018-12-30',
#    'team1': 'Manchester United FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [4, 1]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-01',
#    'team1': 'Everton FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-01',
#    'team1': 'Arsenal FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [4, 1]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-01',
#    'team1': 'Cardiff City FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-02',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-02',
#    'team1': 'Chelsea FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-02',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-02',
#    'team1': 'West Ham United FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-02',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Watford FC',
#    'score': {'ft': [3, 3]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-02',
#    'team1': 'Newcastle United FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 21',
#    'date': '2019-01-03',
#    'team1': 'Manchester City FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-12',
#    'team1': 'West Ham United FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-12',
#    'team1': 'Leicester City FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-12',
#    'team1': 'Burnley FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-12',
#    'team1': 'Cardiff City FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-12',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-12',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-12',
#    'team1': 'Chelsea FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-13',
#    'team1': 'Everton FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-13',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 22',
#    'date': '2019-01-14',
#    'team1': 'Manchester City FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [4, 3]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'Liverpool FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [4, 3]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'Newcastle United FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'Manchester United FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'Southampton FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'Watford FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'AFC Bournemouth',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-19',
#    'team1': 'Arsenal FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-20',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 23',
#    'date': '2019-01-20',
#    'team1': 'Fulham FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-29',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-29',
#    'team1': 'Fulham FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [4, 2]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-29',
#    'team1': 'Arsenal FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-29',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Everton FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-29',
#    'team1': 'Manchester United FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-29',
#    'team1': 'Newcastle United FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-30',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [4, 0]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-30',
#    'team1': 'Southampton FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-30',
#    'team1': 'Liverpool FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 24',
#    'date': '2019-01-30',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-02',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-02',
#    'team1': 'Chelsea FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [5, 0]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-02',
#    'team1': 'Everton FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-02',
#    'team1': 'Burnley FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-02',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-02',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-02',
#    'team1': 'Cardiff City FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-03',
#    'team1': 'Leicester City FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-03',
#    'team1': 'Manchester City FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 25',
#    'date': '2019-02-04',
#    'team1': 'West Ham United FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-06',
#    'team1': 'Everton FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-09',
#    'team1': 'Fulham FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-09',
#    'team1': 'Liverpool FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-09',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-09',
#    'team1': 'Southampton FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-09',
#    'team1': 'Crystal Palace FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-09',
#    'team1': 'Watford FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-09',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-10',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-10',
#    'team1': 'Manchester City FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [6, 0]}},
#   {'round': 'Matchday 26',
#    'date': '2019-02-11',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-22',
#    'team1': 'Cardiff City FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [1, 5]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-22',
#    'team1': 'West Ham United FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-23',
#    'team1': 'Burnley FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-23',
#    'team1': 'Newcastle United FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-23',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-23',
#    'team1': 'Leicester City FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [1, 4]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-24',
#    'team1': 'Arsenal FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 27',
#    'date': '2019-02-24',
#    'team1': 'Manchester United FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-26',
#    'team1': 'Leicester City FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-26',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-26',
#    'team1': 'Cardiff City FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [0, 3]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-26',
#    'team1': 'Newcastle United FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-27',
#    'team1': 'Arsenal FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [5, 1]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-27',
#    'team1': 'Southampton FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-27',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-27',
#    'team1': 'Liverpool FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [5, 0]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-27',
#    'team1': 'Manchester City FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 28',
#    'date': '2019-02-27',
#    'team1': 'Chelsea FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-02',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-02',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-02',
#    'team1': 'Manchester United FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-02',
#    'team1': 'Burnley FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-02',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-02',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-02',
#    'team1': 'West Ham United FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-03',
#    'team1': 'Watford FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-03',
#    'team1': 'Fulham FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 29',
#    'date': '2019-03-03',
#    'team1': 'Everton FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-09',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-09',
#    'team1': 'Newcastle United FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [3, 2]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-09',
#    'team1': 'Leicester City FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-09',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-09',
#    'team1': 'Cardiff City FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-09',
#    'team1': 'Southampton FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-09',
#    'team1': 'Manchester City FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-10',
#    'team1': 'Liverpool FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [4, 2]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-10',
#    'team1': 'Chelsea FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 30',
#    'date': '2019-03-10',
#    'team1': 'Arsenal FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 31',
#    'date': '2019-03-16',
#    'team1': 'Burnley FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 31',
#    'date': '2019-03-16',
#    'team1': 'West Ham United FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [4, 3]}},
#   {'round': 'Matchday 31',
#    'date': '2019-03-16',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 31',
#    'date': '2019-03-17',
#    'team1': 'Fulham FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 31',
#    'date': '2019-03-17',
#    'team1': 'Everton FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-30',
#    'team1': 'Fulham FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-30',
#    'team1': 'Manchester United FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-30',
#    'team1': 'Leicester City FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-30',
#    'team1': 'Burnley FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-30',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-30',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-30',
#    'team1': 'West Ham United FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-31',
#    'team1': 'Cardiff City FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 32',
#    'date': '2019-03-31',
#    'team1': 'Liverpool FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 32',
#    'date': '2019-04-01',
#    'team1': 'Arsenal FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-02',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-02',
#    'team1': 'Watford FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [4, 1]}},
#   {'round': 'Matchday 27',
#    'date': '2019-04-03',
#    'team1': 'Chelsea FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 31',
#    'date': '2019-04-03',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-03',
#    'team1': 'Manchester City FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-05',
#    'team1': 'Southampton FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-06',
#    'team1': 'Newcastle United FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-06',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 4]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-06',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Burnley FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-07',
#    'team1': 'Everton FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-08',
#    'team1': 'Chelsea FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-12',
#    'team1': 'Leicester City FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-13',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [4, 0]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-13',
#    'team1': 'Fulham FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-13',
#    'team1': 'Burnley FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-13',
#    'team1': 'Southampton FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-13',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [0, 5]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-13',
#    'team1': 'Manchester United FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [2, 1]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-14',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-14',
#    'team1': 'Liverpool FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 34',
#    'date': '2019-04-15',
#    'team1': 'Watford FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 31',
#    'date': '2019-04-16',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-20',
#    'team1': 'Manchester City FC',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-20',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-20',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Watford FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-20',
#    'team1': 'West Ham United FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-20',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Fulham FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-20',
#    'team1': 'Newcastle United FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-21',
#    'team1': 'Everton FC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [4, 0]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-21',
#    'team1': 'Arsenal FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [2, 3]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-21',
#    'team1': 'Cardiff City FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 35',
#    'date': '2019-04-22',
#    'team1': 'Chelsea FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 31',
#    'date': '2019-04-23',
#    'team1': 'Watford FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 33',
#    'date': '2019-04-23',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 31',
#    'date': '2019-04-24',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [3, 1]}},
#   {'round': 'Matchday 31',
#    'date': '2019-04-24',
#    'team1': 'Manchester United FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-26',
#    'team1': 'Liverpool FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [5, 0]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-27',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-27',
#    'team1': 'Fulham FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-27',
#    'team1': 'Southampton FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [3, 3]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-27',
#    'team1': 'Crystal Palace FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-27',
#    'team1': 'Watford FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [1, 2]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-27',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-28',
#    'team1': 'Leicester City FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-28',
#    'team1': 'Burnley FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [0, 1]}},
#   {'round': 'Matchday 36',
#    'date': '2019-04-28',
#    'team1': 'Manchester United FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-03',
#    'team1': 'Everton FC',
#    'team2': 'Burnley FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-04',
#    'team1': 'AFC Bournemouth',
#    'team2': 'Tottenham Hotspur FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-04',
#    'team1': 'Wolverhampton Wanderers FC',
#    'team2': 'Fulham FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-04',
#    'team1': 'West Ham United FC',
#    'team2': 'Southampton FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-04',
#    'team1': 'Cardiff City FC',
#    'team2': 'Crystal Palace FC',
#    'score': {'ft': [2, 3]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-04',
#    'team1': 'Newcastle United FC',
#    'team2': 'Liverpool FC',
#    'score': {'ft': [2, 3]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-05',
#    'team1': 'Chelsea FC',
#    'team2': 'Watford FC',
#    'score': {'ft': [3, 0]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-05',
#    'team1': 'Huddersfield Town AFC',
#    'team2': 'Manchester United FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-05',
#    'team1': 'Arsenal FC',
#    'team2': 'Brighton & Hove Albion FC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 37',
#    'date': '2019-05-06',
#    'team1': 'Manchester City FC',
#    'team2': 'Leicester City FC',
#    'score': {'ft': [1, 0]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Fulham FC',
#    'team2': 'Newcastle United FC',
#    'score': {'ft': [0, 4]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Liverpool FC',
#    'team2': 'Wolverhampton Wanderers FC',
#    'score': {'ft': [2, 0]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Tottenham Hotspur FC',
#    'team2': 'Everton FC',
#    'score': {'ft': [2, 2]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Manchester United FC',
#    'team2': 'Cardiff City FC',
#    'score': {'ft': [0, 2]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Leicester City FC',
#    'team2': 'Chelsea FC',
#    'score': {'ft': [0, 0]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Burnley FC',
#    'team2': 'Arsenal FC',
#    'score': {'ft': [1, 3]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Southampton FC',
#    'team2': 'Huddersfield Town AFC',
#    'score': {'ft': [1, 1]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Crystal Palace FC',
#    'team2': 'AFC Bournemouth',
#    'score': {'ft': [5, 3]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Brighton & Hove Albion FC',
#    'team2': 'Manchester City FC',
#    'score': {'ft': [1, 4]}},
#   {'round': 'Matchday 38',
#    'date': '2019-05-12',
#    'team1': 'Watford FC',
#    'team2': 'West Ham United FC',
#    'score': {'ft': [1, 4]}}]}

# %% [markdown]
# **Explanation:** Season 2010/11 to 2017/18 and season 2018/19 to 2020/21 has a different nested dict-list format.

# %%
matchesPart1 = [] # season 2010/11
for x1 in pythonData[0:8]:
    seasonValue = x1['name']  # pythonData[i]['name'] value
    nestedList1 = x1['rounds']  # pythonData[i]['rounds'] list
    for x2 in nestedList1:
        matchdayValue = x2['name'] # pythonData[i]['rounds'][i]['name'] value
        nestedList2 = x2['matches'] # pythonData[i]['rounds'][i]['matches'] list
        for x3 in nestedList2:
            dateValue = x3['date'] # pythonData[i]['rounds'][i]['matches'][i]['date'] value
            hometeamValue = x3['team1'] # pythonData[i]['rounds'][i]['matches'][i]['team1'] value
            awayteamValue = x3['team2'] # pythonData[i]['rounds'][i]['matches'][i]['team2'] value
            hometeamScoreValue = x3['score']['ft'][0] # pythonData[i]['rounds'][i]['matches'][i]['score']['ft'][0] value
            awayteamScoreValue = x3['score']['ft'][1] # pythonData[i]['rounds'][i]['matches'][i]['score']['ft'][1] value
            matchesPart1.append({
                'season' : seasonValue,
                'matchday' : matchdayValue,
                'date' : dateValue,
                'home_team' : hometeamValue,
                'away_team' : awayteamValue,
                'home_goals' : hometeamScoreValue,
                'away_goals' : awayteamScoreValue
            })

matchesPart2 = [] # season 2018/19
for x1 in pythonData[8:]:
    seasonValue = x1['name']  # pythonData[i]['name'] value
    nestedList1 = x1['matches']  # pythonData[i]['matches'] list
    for x2 in nestedList1:
        matchdayValue = x2['round'] # pythonData[i]['matches'][i]['round'] value
        dateValue = x2['date'] # pythonData[i]['matches'][i]['date'] value
        hometeamValue = x2['team1'] # pythonData[i]['matches'][i]['team1'] value
        awayteamValue = x2['team2'] # pythonData[i]['matches'][i]['team2'] value
        if ('score' in x2.keys()) == True:
            hometeamScoreValue = x2['score']['ft'][0] # pythonData[i]['matches'][i]['score']['ft'][0] value
            awayteamScoreValue = x2['score']['ft'][1] # pythonData[i]['matches'][i]['score']['ft'][1] value
            matchesPart2.append({
                'season' : seasonValue,
                'matchday' : matchdayValue,
                'date' : dateValue,
                'home_team' : hometeamValue,
                'away_team' : awayteamValue,
                'home_goals' : hometeamScoreValue,
                'away_goals' : awayteamScoreValue
            })
        else:
            matchesPart2.append({
                'season' : seasonValue,
                'matchday' : matchdayValue,
                'date' : dateValue,
                'home_team' : hometeamValue,
                'away_team' : awayteamValue,
                'home_goals' : None,
                'away_goals' : None
            })

# create dataframe
tempdfPart1 = pd.DataFrame(matchesPart1) # season 2010/11
tempdfPart2 = pd.DataFrame(matchesPart2) # season 2018/19
dfMatches = tempdfPart1.append(tempdfPart2)

dfMatches.sample(5)
# Out:
#                       season     matchday        date             home_team  \
# 388   Premier League 2019/20   Matchday 1  2019-08-11   Newcastle United FC
# 11    Premier League 2018/19   Matchday 2  2018-08-18  Tottenham Hotspur FC
# 2291  Premier League 2016/17   Matchday 2  2016-08-20         Stoke City FC
# 1139  Premier League 2012/13  Matchday 38  2013-05-19     Wigan Athletic FC
# 1269  Premier League 2013/14  Matchday 13  2013-12-01            Chelsea FC
#
#                away_team  home_goals  away_goals
# 388           Arsenal FC         0.0         1.0
# 11             Fulham FC         3.0         1.0
# 2291  Manchester City FC         1.0         4.0
# 1139      Aston Villa FC         2.0         2.0
# 1269      Southampton FC         3.0         1.0

# %%
dfMatches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4180 entries, 0 to 1139
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      4180 non-null   object
#  1   matchday    4180 non-null   object
#  2   date        4180 non-null   object
#  3   home_team   4180 non-null   object
#  4   away_team   4180 non-null   object
#  5   home_goals  3879 non-null   float64
#  6   away_goals  3879 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 261.2+ KB

# %% [markdown]
# **Explanation:**
# - Data type of `date` need to change to date
# - Data type of `home_goals` and `away_goals` need to change to integer
# - There are 301 null values in each of `home_goals` and `away_goals`

# %% [markdown]
# ## CLEANSE DATA

# %% [markdown]
# ### Duplicated Values

# %% [markdown]
# Check if there are duplicated values.

# %%
dfMatches.duplicated().any()
# Out:
# False

# %% [markdown]
# **Explanation:** There are no duplicated values.

# %% [markdown]
# ### Null Values

# %% [markdown]
# There are null values in `home_goals` and `away_goals`.

# %%
dfTemp = dfMatches.loc[dfMatches['home_goals'].isnull() | dfMatches['home_goals'].isnull()] # filter by null value
dfTemp[['season', 'matchday', 'date', 'home_team', 'away_team']].describe() # string statistics
# Out:
#                         season     matchday        date   home_team  \
# count                      301          301         301         301
# unique                       1           31          40          20
# top     Premier League 2020/21  Matchday 23  2021-01-30  Burnley FC
# freq                       301           10          10          16
#
#                    away_team
# count                    301
# unique                    20
# top     Manchester United FC
# freq                      16

# %%
dfTemp['matchday'].unique() # matchday list that contains null value
# Out:
# array(['Matchday 1', 'Matchday 9', 'Matchday 10', 'Matchday 11',
#        'Matchday 12', 'Matchday 13', 'Matchday 14', 'Matchday 15',
#        'Matchday 16', 'Matchday 17', 'Matchday 18', 'Matchday 19',
#        'Matchday 20', 'Matchday 21', 'Matchday 22', 'Matchday 23',
#        'Matchday 24', 'Matchday 25', 'Matchday 26', 'Matchday 27',
#        'Matchday 28', 'Matchday 29', 'Matchday 30', 'Matchday 31',
#        'Matchday 32', 'Matchday 33', 'Matchday 34', 'Matchday 35',
#        'Matchday 36', 'Matchday 37', 'Matchday 38'], dtype=object)

# %% [markdown]
# **Explanation:** Null values on matchday 1 and 9 to 38 in season 2020/21. Numeric data for that season can't be processed.

# %%
# remove data
dfMatchesClean = dfMatches.copy()
dfMatchesClean = dfMatchesClean.loc[~(dfMatches['season'] == 'Premier League 2020/21')]

# change data type
dfMatchesClean['date'] = pd.to_datetime(dfMatchesClean['date']) # str to date
dfMatchesClean = dfMatchesClean.astype({
    'home_goals' : 'int64', # float to int
    'away_goals' : 'int64' # float to int
})

dfMatchesClean.head(2)
# Out:
#                    season    matchday       date            home_team  \
# 0  Premier League 2010/11  Matchday 1 2010-08-14  Bolton Wanderers FC
# 1  Premier League 2010/11  Matchday 1 2010-08-14    Wigan Athletic FC
#
#       away_team  home_goals  away_goals
# 0     Fulham FC           0           0
# 1  Blackpool FC           0           4

# %% [markdown]
# We have clean dataframe `dfMatchesClean` which contains season from 2010/11 to 2019/20 with goals data.

# %% [markdown]
# # DATA PROCESSING

# %%
dfMatchesComplete = dfMatchesClean.copy()

# split columns
seasonStartList = dfMatchesComplete['season'].str.split(expand = True)[2].str.split('/', expand = True)[0]
matchdayList = dfMatchesComplete['matchday'].str.split(expand = True)[1]
dfMatchesComplete['season'] = seasonStartList
dfMatchesComplete['matchday'] = matchdayList
dfMatchesComplete = dfMatchesComplete.rename({'season' : 'season_start'}, axis = 1)

# drop columns
# dfMatchesComplete = dfMatchesComplete.drop(columns = ['date'], axis = 1)

# change data type
dfMatchesComplete = dfMatchesComplete.astype({
    'season_start' : 'int64',
    'matchday' : 'int64'
})

dfMatchesComplete = dfMatchesComplete.sort_values([
    'season_start',
    'matchday',
    'date',
    'home_team'
]).reset_index(drop = True)

dfMatchesComplete.head(2)
# Out:
#    season_start  matchday       date            home_team           away_team  \
# 0          2010         1 2010-08-14       Aston Villa FC  West Ham United FC
# 1          2010         1 2010-08-14  Blackburn Rovers FC          Everton FC
#
#    home_goals  away_goals
# 0           3           0
# 1           1           0

# %%
# home-away clean sheet by goals condition
homeCleanSheet = []
awayCleanSheet = []
for ((index1, value1), (index2, value2)) in zip(dfMatchesComplete['home_goals'].items(), dfMatchesComplete['away_goals'].items()):
    if value1 == 0:
        homeCleanSheet.append(True)
    else:
        homeCleanSheet.append(False)
    if value2 == 0:
        awayCleanSheet.append(True)
    else:
        awayCleanSheet.append(False)

# home-away point and result by goals condition
homePoint = []
awayPoint = []
homeResult = []
awayResult = []
for ((index1, value1), (index2, value2)) in zip(dfMatchesComplete['home_goals'].items(), dfMatchesComplete['away_goals'].items()):
    if value1 > value2:
        homePoint.append(3)
        awayPoint.append(0)
        homeResult.append('Won')
        awayResult.append('Loss')
    elif value1 < value2:
        homePoint.append(0)
        awayPoint.append(3)
        homeResult.append('Loss')
        awayResult.append('Won')
    else:
        homePoint.append(1)
        awayPoint.append(1)
        homeResult.append('Draw')
        awayResult.append('Draw')

# create new columns
dfMatchesComplete['is_home_cleansheet'] = homeCleanSheet
dfMatchesComplete['is_away_cleansheet'] = awayCleanSheet
dfMatchesComplete['home_point'] = homePoint
dfMatchesComplete['away_point'] = awayPoint
dfMatchesComplete['home_result'] = homeResult
dfMatchesComplete['away_result'] = awayResult

dfMatchesComplete.head(2)
# Out:
#    season_start  matchday       date            home_team           away_team  \
# 0          2010         1 2010-08-14       Aston Villa FC  West Ham United FC
# 1          2010         1 2010-08-14  Blackburn Rovers FC          Everton FC
#
#    home_goals  away_goals  is_home_cleansheet  is_away_cleansheet  home_point  \
# 0           3           0               False                True           3
# 1           1           0               False                True           3
#
#    away_point home_result away_result
# 0           0         Won        Loss
# 1           0         Won        Loss

# %%
# home team
dfHomeMatches = dfMatchesComplete.copy()
dfHomeMatches['side'] = 'Home'
dfHomeMatches = dfHomeMatches[[
    'season_start',
    'matchday',
    'date',
    'home_team',
    'side',
    'home_goals',
    'away_goals',
    'is_home_cleansheet',
    'home_point',
    'home_result'
]]
dfHomeMatches = dfHomeMatches.rename({
    'home_team' : 'team',
    'home_goals' : 'goals_scored',
    'away_goals' : 'goals_concedad',
    'is_home_cleansheet' : 'is_cleansheet',
    'home_point' : 'point',
    'home_result' : 'result',
}, axis = 1)

# away team
dfAwayMatches = dfMatchesComplete.copy()
dfAwayMatches['side'] = 'Away'
dfAwayMatches = dfAwayMatches[[
    'season_start',
    'matchday',
    'date',
    'away_team',
    'side',
    'away_goals',
    'home_goals',
    'is_away_cleansheet',
    'away_point',
    'away_result'
]]
dfAwayMatches = dfAwayMatches.rename({
    'away_team' : 'team',
    'away_goals' : 'goals_scored',
    'home_goals' : 'goals_concedad',
    'is_away_cleansheet' : 'is_cleansheet',
    'away_point' : 'point',
    'away_result' : 'result',
}, axis = 1)

# union home-away team
dfTeamResult = dfHomeMatches.append(dfAwayMatches)
dfTeamResult = dfTeamResult.sort_values([
    'season_start',
    'matchday',
    'date',
    'team'
]).reset_index(drop = True)

dfTeamResult.iloc[[1, 2, 3799, 3800, 7598, 7599]]
# Out:
#       season_start  matchday       date                        team  side  \
# 1             2010         1 2010-08-14          Birmingham City FC  Away
# 2             2010         1 2010-08-14         Blackburn Rovers FC  Home
# 3799          2014        38 2015-05-24          West Ham United FC  Away
# 3800          2015         1 2015-08-08             AFC Bournemouth  Home
# 7598          2019        38 2020-07-26          West Ham United FC  Home
# 7599          2019        38 2020-07-26  Wolverhampton Wanderers FC  Away
#
#       goals_scored  goals_concedad  is_cleansheet  point result
# 1                2               2          False      1   Draw
# 2                1               0          False      3    Won
# 3799             0               2           True      0   Loss
# 3800             0               1           True      0   Loss
# 7598             1               1          False      1   Draw
# 7599             0               2           True      0   Loss

# %%
# create pivot table
goalsScoredPivot = pd.pivot_table(
    data = dfTeamResult,
    values = 'goals_scored',
    index = ['team'],
    columns = ['season_start', 'matchday'],
    fill_value = 0,
    aggfunc = 'sum',
)
goalsScoredPivot = goalsScoredPivot.cumsum(axis = 1)

columnLevel0 = goalsScoredPivot.columns.get_level_values(0).tolist()
columnLevel1 = goalsScoredPivot.columns.get_level_values(1).tolist()
columnName = []
for col1, col2 in zip(columnLevel0, columnLevel1):
    columnName.append(str(col1) + '/' + str(col1 + 1) + ' - Matchday ' + str(col2))
goalsScoredPivot.columns = columnName

urlLogoMain = 'https://raw.githubusercontent.com/faisalydth/MP-EPL1020/main/Logo/'
urlLogo = []
for x in range(1, 37):
    urlLogo.append(urlLogoMain + str(x) + '.svg')
goalsScoredPivot['logo_url'] = urlLogo

goalsScoredPivot
# Out:
#                             2010/2011 - Matchday 1  2010/2011 - Matchday 2  \
# team
# AFC Bournemouth                                  0                       0
# Arsenal FC                                       1                       7
# Aston Villa FC                                   3                       3
# Birmingham City FC                               2                       4
# Blackburn Rovers FC                              1                       2
# Blackpool FC                                     4                       4
# Bolton Wanderers FC                              0                       3
# Queens Park Rangers FC                          115                      115
# Reading FC                                       43                       43
# Sheffield United FC                              38                       39
# Southampton FC                                  387                      390
# Stoke City FC                                   326                      326
# Sunderland AFC                                  280                      280
# Swansea City FC                                 306                      306
# Tottenham Hotspur FC                            656                      657
# Watford FC                                      210                      212
# West Bromwich Albion FC                         343                      343
# West Ham United FC                              432                      433
# Wigan Athletic FC                               129                      129
# Wolverhampton Wanderers FC                      184                      184
#
#                                                                      logo_url
# team
# AFC Bournemouth             https://raw.githubusercontent.com/faisalydth/M...
# Arsenal FC                  https://raw.githubusercontent.com/faisalydth/M...
# Aston Villa FC              https://raw.githubusercontent.com/faisalydth/M...
# Birmingham City FC          https://raw.githubusercontent.com/faisalydth/M...
# Blackburn Rovers FC         https://raw.githubusercontent.com/faisalydth/M...
# Blackpool FC                https://raw.githubusercontent.com/faisalydth/M...
# Bolton Wanderers FC         https://raw.githubusercontent.com/faisalydth/M...
# Brighton & Hove Albion FC   https://raw.githubusercontent.com/faisalydth/M...
# Burnley FC                  https://raw.githubusercontent.com/faisalydth/M...
# Cardiff City FC             https://raw.githubusercontent.com/faisalydth/M...
# Chelsea FC                  https://raw.githubusercontent.com/faisalydth/M...
# Crystal Palace FC           https://raw.githubusercontent.com/faisalydth/M...
# Everton FC                  https://raw.githubusercontent.com/faisalydth/M...
# Fulham FC                   https://raw.githubusercontent.com/faisalydth/M...
# Huddersfield Town AFC       https://raw.githubusercontent.com/faisalydth/M...
# Hull City AFC               https://raw.githubusercontent.com/faisalydth/M...
# Leicester City FC           https://raw.githubusercontent.com/faisalydth/M...
# Liverpool FC                https://raw.githubusercontent.com/faisalydth/M...
# Manchester City FC          https://raw.githubusercontent.com/faisalydth/M...
# Manchester United FC        https://raw.githubusercontent.com/faisalydth/M...
# Middlesbrough FC            https://raw.githubusercontent.com/faisalydth/M...
# Newcastle United FC         https://raw.githubusercontent.com/faisalydth/M...
# Norwich City FC             https://raw.githubusercontent.com/faisalydth/M...
# Queens Park Rangers FC      https://raw.githubusercontent.com/faisalydth/M...
# Reading FC                  https://raw.githubusercontent.com/faisalydth/M...
# Sheffield United FC         https://raw.githubusercontent.com/faisalydth/M...
# Southampton FC              https://raw.githubusercontent.com/faisalydth/M...
# Stoke City FC               https://raw.githubusercontent.com/faisalydth/M...
# Sunderland AFC              https://raw.githubusercontent.com/faisalydth/M...
# Swansea City FC             https://raw.githubusercontent.com/faisalydth/M...
# Tottenham Hotspur FC        https://raw.githubusercontent.com/faisalydth/M...
# Watford FC                  https://raw.githubusercontent.com/faisalydth/M...
# West Bromwich Albion FC     https://raw.githubusercontent.com/faisalydth/M...
# West Ham United FC          https://raw.githubusercontent.com/faisalydth/M...
# Wigan Athletic FC           https://raw.githubusercontent.com/faisalydth/M...
# Wolverhampton Wanderers FC  https://raw.githubusercontent.com/faisalydth/M...
#
# [36 rows x 381 columns]

# %%
# save to CSV
goalsScoredPivot.to_csv('Table-GoalsScored.csv', index = True)
